# %%
def transform_reward(DB_FILE: str, reward_value: str):
    """
    Transforms integer reward values to their string counterparts, or vice-versa.

    Args:
        DB_FILE (str): Path to database file
        reward_value (str | int): The reward value, either as integer or string type, to convert to the other type.
    """
    # Mapping of reward values
    reward_dict = {
        "0": "low",
        "1": "medium",
        "2": "high"
    }
    # new value becomes the counterpart value
    if reward_value in ["0", "1", "2"]:
        new_reward_value = reward_dict[reward_value]
    else:
        new_reward_value = reward_dict.values[int(reward_value)]
