# %%
import time

start_time = time.time()
time.sleep(2)
elapsed_time = int(time.time() - start_time)

formatted_time = time.strftime("%H:%M:%S", elapsed_time)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 time.sleep(2)
#       5 elapsed_time = time.time() - start_time
# ----> 7 formatted_time = time.strftime("%H:%M:%S", elapsed_time)
#
# TypeError: Tuple or struct_time argument required

# %%
task_timers = []
if len(task_timers) != 0:
    print("Object is there!")
else:
    print("Object not created yet")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 task_timers = []
# ----> 2 if task_timers[0] is not None:
#       3     print("Object is there!")
#       4 else:
#
# IndexError: list index out of range

# %%
len(task_timers)
# Out:
# 0
